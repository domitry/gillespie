# %%
# %matplotlib inline

# %%
from gillespie import *

# %%
A = Species('A')
B = Species('B')

# %%
sim = Simulator(A, B)

# %%
alpha1 = 156.25
alpha2 = 15.6
beta = 2.5
gamma = 1

# %%
def r1(sim):
    sim.increment()

# %%
sim.increment(A, 10)
sim.increment(B, 5)

# %%
sim.run(100)

# %%
sim.plot()
